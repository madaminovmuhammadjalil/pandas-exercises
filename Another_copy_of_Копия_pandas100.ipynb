# %% [markdown]
# <a href="https://colab.research.google.com/github/madaminovmuhammadjalil/pandas-exercises/blob/main/Another_copy_of_%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_pandas100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import DataFrame as df
import pandas as pd

# %%
# 1-masala
dict_ex1 = {
    "ismlar":["ali","soli"],
    "familiyalar":["karimov","jabborov"]
}
df_ex1 = df(dict_ex1)
df_ex1
# Out:
#   ismlar familiyalar
# 0    ali     karimov
# 1   soli    jabborov

# %%
# 2-masala
list_ex2 = [["karim","aliyev",23],["salim","jabborov",18]]
df_ex2 = df(list_ex2,columns=["name","last_name","age"])
df_ex2
# Out:
#     name last_name  age
# 0  karim    aliyev   23
# 1  salim  jabborov   18

# %%
# 3-masala
dc = {
    "subject":["math","physics","informatics"],
    "teacher":["axror","rasul","jabbor"]
}
dct = {
    "student":["jasul","axror","oygul"],
    "grades":[5,4,4]
}
dct_ex3 = df(dc)
dct_ex3.index.name = "id"
dict_ex3 = df(dct)
dict_ex3.index.name = "id"
dict_main = dct_ex3.merge(dict_ex3,on="id",how="left")
dict_main
# Out:
#         subject teacher student  grades
# id
# 0          math   axror   jasul       5
# 1       physics   rasul   axror       4
# 2   informatics  jabbor   oygul       4

# %%
# 4-masala
df = df.rename(columns={"name": "ism", "age": "yosh"})

# %%
# 5-masala
df.index.name = "raqam"

# %%
# 6-masala
df = df[["yosh", "ism"]]

# %%
# 7-masala
df["country"] = "Uzbekistan"

# %%
# 8-masala
df["yosh_plus_5"] = df["yosh"] + 5

# %%
# 9-masala
df["full_info"] = df["ism"] + " - " + df["country"]

# %%
# 10-masala
csv_text = df.to_csv(index=True)

# %%
employees = pd.DataFrame({
    "id": [1, 2, 3, 4, 5],
    "name": ["Ali", "Vali", "Hasan", "Husan", "Olim"],
    "age": [25, 30, 22, 35, 28],
    "salary": [500, 700, 450, 900, 800],
    "city": ["Toshkent", "Samarqand", "Buxoro", "Toshkent", "Samarqand"]
})
orders = pd.DataFrame({
    "order_id": [101, 102, 103, 104, 105, 106],
    "user_id": [1, 1, 2, 3, 3, 5],
    "amount": [120, 150, 300, 80, 60, 500]
})

products = pd.DataFrame({
    "product_id": [10, 20, 30, 40],
    "name": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "price": [500, 20, 30, 150]
})
sales = pd.DataFrame({
    "date": pd.date_range("2024-01-01", periods=10, freq="D"),
    "sales": [100, 120, 130, 90, 80, 200, 220, 150, 170, 300]
})
text_df = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "text": ["Hello World", "pandas IS powerful", "  spaced text  ", "Data-Science!!!"]
})

# %%
# 11-masala
employees["name"]
# Out:
# 0      Ali
# 1     Vali
# 2    Hasan
# 3    Husan
# 4     Olim
# Name: name, dtype: object

# %%
# 12
employees[["name","age"]]
# Out:
#     name  age
# 0    Ali   25
# 1   Vali   30
# 2  Hasan   22
# 3  Husan   35
# 4   Olim   28

# %%
# 13
employees.head(3)
# Out:
#    id   name  age  salary       city
# 0   1    Ali   25     500   Toshkent
# 1   2   Vali   30     700  Samarqand
# 2   3  Hasan   22     450     Buxoro

# %%
# 14
employees.tail(2)
# Out:
#    id   name  age  salary       city
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand

# %%
# 15
employees.loc[3]
# Out:
# id               4
# name         Husan
# age             35
# salary         900
# city      Toshkent
# Name: 3, dtype: object

# %%
# 16
employees.iloc[2,1]
# Out:
# 'Hasan'

# %%
# 17
employees.iloc[2:4,:]
# Out:
#    id   name  age  salary      city
# 2   3  Hasan   22     450    Buxoro
# 3   4  Husan   35     900  Toshkent

# %%
# 18
employees.loc[employees["city"]=="Toshkent"]
# Out:
#    id   name  age  salary      city
# 0   1    Ali   25     500  Toshkent
# 3   4  Husan   35     900  Toshkent

# %%
# 19
employees[["salary"]]
# Out:
#    salary
# 0     500
# 1     700
# 2     450
# 3     900
# 4     800

# %%
# 20
employees.shape
# Out:
# (5, 5)

# %%
# 21
employees.columns
# Out:
# Index(['id', 'name', 'age', 'salary', 'city'], dtype='object')

# %%
# 22
employees.index = ["a","b","c","d","e"]
employees.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# 23
employees.dtypes
# Out:
# id         int64
# name      object
# age        int64
# salary     int64
# city      object
# dtype: object

# %%
# 24
employees
employees.nunique()
# Out:
# id        5
# name      5
# age       5
# salary    5
# city      3
# dtype: int64

# %%
# 25
employees.describe()
# Out:
#              id        age      salary
# count  5.000000   5.000000    5.000000
# mean   3.000000  28.000000  670.000000
# std    1.581139   4.949747  192.353841
# min    1.000000  22.000000  450.000000
# 25%    2.000000  25.000000  500.000000
# 50%    3.000000  28.000000  700.000000
# 75%    4.000000  30.000000  800.000000
# max    5.000000  35.000000  900.000000

# %%
employees
# Out:
#    id   name  age  salary       city
# a   1    Ali   25     500   Toshkent
# b   2   Vali   30     700  Samarqand
# c   3  Hasan   22     450     Buxoro
# d   4  Husan   35     900   Toshkent
# e   5   Olim   28     800  Samarqand

# %%
# 26
employees[employees["age"]>25]
# Out:
#    id   name  age  salary       city
# 1   2   Vali   30     700  Samarqand
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand

# %%
# 27
employees[employees["salary"]>=700]
# Out:
#    id   name  age  salary       city
# 1   2   Vali   30     700  Samarqand
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand

# %%
# 28
employees[employees["city"]=="Toshkent"]
# Out:
#    id   name  age  salary      city
# 0   1    Ali   25     500  Toshkent
# 3   4  Husan   35     900  Toshkent

# %%
# 29
employees[(employees["age"]<30) | (employees["salary"]>600)]
# Out:
#    id   name  age  salary       city
# 0   1    Ali   25     500   Toshkent
# 1   2   Vali   30     700  Samarqand
# 2   3  Hasan   22     450     Buxoro
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand

# %%
# 30
employees[(employees["city"]=="Toshkent") | (employees["city"]=="Buxoro")]
# Out:
#    id   name  age  salary      city
# 0   1    Ali   25     500  Toshkent
# 2   3  Hasan   22     450    Buxoro
# 3   4  Husan   35     900  Toshkent

# %%
# 31
employees[employees["name"]=="Ali"]
# Out:
#    id name  age  salary      city
# 0   1  Ali   25     500  Toshkent

# %%
# 32
employees[employees["salary"].between(500,800)]
# Out:
#    id  name  age  salary       city
# 0   1   Ali   25     500   Toshkent
# 1   2  Vali   30     700  Samarqand
# 4   5  Olim   28     800  Samarqand

# %%
# 33
employees[employees["age"]%2==0]
# Out:
#    id   name  age  salary       city
# 1   2   Vali   30     700  Samarqand
# 2   3  Hasan   22     450     Buxoro
# 4   5   Olim   28     800  Samarqand

# %%
#34
employees[employees["name"].str.startswith("H")]
# Out:
#    id   name  age  salary      city
# 2   3  Hasan   22     450    Buxoro
# 3   4  Husan   35     900  Toshkent

# %%
# 35
employees[employees["name"].str.contains("a")]
# Out:
#    id   name  age  salary       city
# 1   2   Vali   30     700  Samarqand
# 2   3  Hasan   22     450     Buxoro
# 3   4  Husan   35     900   Toshkent

# %%
# 36
employees[employees["age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, name, age, salary, city]
# Index: []

# %%
# 37
employees[employees["salary"].notnull()]
# Out:
#    id   name  age  salary       city
# 0   1    Ali   25     500   Toshkent
# 1   2   Vali   30     700  Samarqand
# 2   3  Hasan   22     450     Buxoro
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand

# %%
# 38
employees[employees["name"].str.len()>4]
# Out:
#    id   name  age  salary      city
# 2   3  Hasan   22     450    Buxoro
# 3   4  Husan   35     900  Toshkent

# %%
# 39
employees[employees["salary"]==employees["salary"].max()]
# Out:
#    id   name  age  salary      city
# 3   4  Husan   35     900  Toshkent

# %%
# 40
employees[employees["salary"]==employees["salary"].min()]
# Out:
#    id   name  age  salary    city
# 2   3  Hasan   22     450  Buxoro

# %%
# 41
employees.sort_values(["age"])
# Out:
#    id   name  age  salary       city
# 2   3  Hasan   22     450     Buxoro
# 0   1    Ali   25     500   Toshkent
# 4   5   Olim   28     800  Samarqand
# 1   2   Vali   30     700  Samarqand
# 3   4  Husan   35     900   Toshkent

# %%
# 42
employees.sort_values(["salary"],ascending=False)
# Out:
#    id   name  age  salary       city
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand
# 1   2   Vali   30     700  Samarqand
# 0   1    Ali   25     500   Toshkent
# 2   3  Hasan   22     450     Buxoro

# %%
# 43
employees.sort_values(["city","age"])
# Out:
#    id   name  age  salary       city
# 2   3  Hasan   22     450     Buxoro
# 4   5   Olim   28     800  Samarqand
# 1   2   Vali   30     700  Samarqand
# 0   1    Ali   25     500   Toshkent
# 3   4  Husan   35     900   Toshkent

# %%
# 44
employees.sort_values(["name"],ascending=True)
# Out:
#    id   name  age  salary       city
# 0   1    Ali   25     500   Toshkent
# 2   3  Hasan   22     450     Buxoro
# 3   4  Husan   35     900   Toshkent
# 4   5   Olim   28     800  Samarqand
# 1   2   Vali   30     700  Samarqand

# %%
# 45
employees["len"] = employees["name"].str.len()
employees.sort_values("len",ascending=True)
# Out:
#    id   name  age  salary       city  len
# 0   1    Ali   25     500   Toshkent    3
# 1   2   Vali   30     700  Samarqand    4
# 4   5   Olim   28     800  Samarqand    4
# 2   3  Hasan   22     450     Buxoro    5
# 3   4  Husan   35     900   Toshkent    5

# %%
# 46
orders.sort_values(["amount"])
# Out:
#    order_id  user_id  amount
# 4       105        3      60
# 3       104        3      80
# 0       101        1     120
# 1       102        1     150
# 2       103        2     300
# 5       106        5     500

# %%
# 47
sales.sort_values(["sales"])
# Out:
#         date  sales
# 4 2024-01-05     80
# 3 2024-01-04     90
# 0 2024-01-01    100
# 1 2024-01-02    120
# 2 2024-01-03    130
# 7 2024-01-08    150
# 8 2024-01-09    170
# 5 2024-01-06    200
# 6 2024-01-07    220
# 9 2024-01-10    300

# %%
# 48
employees.sort_values(by=["salary","city"],ascending=[False,True])
# Out:
#    id   name  age  salary       city  len
# 3   4  Husan   35     900   Toshkent    5
# 4   5   Olim   28     800  Samarqand    4
# 1   2   Vali   30     700  Samarqand    4
# 0   1    Ali   25     500   Toshkent    3
# 2   3  Hasan   22     450     Buxoro    5

# %%
# 49
employees.sort_values(["salary"],ascending=False).head(3)
# Out:
#    id   name  age  salary       city  len
# 3   4  Husan   35     900   Toshkent    5
# 4   5   Olim   28     800  Samarqand    4
# 1   2   Vali   30     700  Samarqand    4

# %%
# 50
employees.sort_values(["salary"],ascending=False).tail(2)
# Out:
#    id   name  age  salary      city  len
# 0   1    Ali   25     500  Toshkent    3
# 2   3  Hasan   22     450    Buxoro    5
