# %% [markdown]
# <a href="https://colab.research.google.com/github/madaminovmuhammadjalil/pandas-exercises/blob/main/Another_copy_of_%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_pandas100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import DataFrame as df
import pandas as pd

# %%
# 1-masala
dict_ex1 = {
    "ismlar":["ali","soli"],
    "familiyalar":["karimov","jabborov"]
}
df_ex1 = df(dict_ex1)
df_ex1
# Out:
#   ismlar familiyalar
# 0    ali     karimov
# 1   soli    jabborov

# %%
# 2-masala
list_ex2 = [["karim","aliyev",23],["salim","jabborov",18]]
df_ex2 = df(list_ex2,columns=["name","last_name","age"])
df_ex2
# Out:
#     name last_name  age
# 0  karim    aliyev   23
# 1  salim  jabborov   18

# %%
# 3-masala
dc = {
    "subject":["math","physics","informatics"],
    "teacher":["axror","rasul","jabbor"]
}
dct = {
    "student":["jasul","axror","oygul"],
    "grades":[5,4,4]
}
dct_ex3 = df(dc)
dct_ex3.index.name = "id"
dict_ex3 = df(dct)
dict_ex3.index.name = "id"
dict_main = dct_ex3.merge(dict_ex3,on="id",how="left")
dict_main
# Out:
#         subject teacher student  grades
# id
# 0          math   axror   jasul       5
# 1       physics   rasul   axror       4
# 2   informatics  jabbor   oygul       4

# %%
# 4-masala
df = df.rename(columns={"name": "ism", "age": "yosh"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-557155629.py in <cell line: 0>()
#       1 # 4-masala
# ----> 2 df = df.rename(columns={"name": "ism", "age": "yosh"})
#       3
#
# TypeError: DataFrame.rename() missing 1 required positional argument: 'self'

# %%
# 5-masala
df.index.name = "raqam"

# %%
# 6-masala
df = df[["yosh", "ism"]]

# %%
# 7-masala
df["country"] = "Uzbekistan"

# %%
# 8-masala
df["yosh_plus_5"] = df["yosh"] + 5

# %%
# 9-masala
df["full_info"] = df["ism"] + " - " + df["country"]

# %%
# 10-masala
csv_text = df.to_csv(index=True)

# %%
employees = pd.DataFrame({
    "id": [1, 2, 3, 4, 5],
    "name": ["Ali", "Vali", "Hasan", "Husan", "Olim"],
    "age": [25, 30, 22, 35, 28],
    "salary": [500, 700, 450, 900, 800],
    "city": ["Toshkent", "Samarqand", "Buxoro", "Toshkent", "Samarqand"]
})
orders = pd.DataFrame({
    "order_id": [101, 102, 103, 104, 105, 106],
    "user_id": [1, 1, 2, 3, 3, 5],
    "amount": [120, 150, 300, 80, 60, 500]
})

products = pd.DataFrame({
    "product_id": [10, 20, 30, 40],
    "name": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "price": [500, 20, 30, 150]
})
sales = pd.DataFrame({
    "date": pd.date_range("2024-01-01", periods=10, freq="D"),
    "sales": [100, 120, 130, 90, 80, 200, 220, 150, 170, 300]
})
text_df = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "text": ["Hello World", "pandas IS powerful", "  spaced text  ", "Data-Science!!!"]
})

# %%
# 11-masala
employees["name"]

# %%
# 12
employees[["name","age"]]

# %%
# 13
employees.head(3)

# %%
# 14
employees.tail(2)

# %%
# 15
employees.loc[3]
# Out:
# id                 4
# name           Husan
# age             35.0
# salary           900
# city        Toshkent
# name_len           5
# onlik            3.0
# Name: 3, dtype: object

# %%
# 16
employees.iloc[2,1]
# Out:
# 'Hasan'

# %%
# 17
employees.iloc[2:4,:]
# Out:
#    id   name   age  salary      city  name_len  onlik
# 2   3  Hasan  22.0     450    Buxoro         5    2.0
# 3   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 18
employees.loc[employees["city"]=="Toshkent"]
# Out:
#    id   name   age  salary      city  name_len  onlik
# 0   1    Ali   NaN     500  Toshkent         3    NaN
# 3   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 19
employees[["salary"]]
# Out:
#    salary
# 0     500
# 1     700
# 2     450
# 3     900
# 4     800

# %%
# 20
employees.shape
# Out:
# (5, 7)

# %%
# 21
employees.columns
# Out:
# Index(['id', 'name', 'age', 'salary', 'city', 'name_len', 'onlik'], dtype='object')

# %%
# 22
employees.index = ["a","b","c","d","e"]
employees.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# 23
employees.dtypes
# Out:
# id            int64
# name         object
# age         float64
# salary        int64
# city         object
# name_len      int64
# onlik       float64
# dtype: object

# %%
# 24
employees
employees.nunique()
# Out:
# id          5
# name        5
# age         4
# salary      5
# city        3
# name_len    3
# onlik       3
# dtype: int64

# %%
# 25
employees.describe()
# Out:
#              id         age      salary  name_len      onlik
# count  5.000000    4.000000    5.000000   5.00000   4.000000
# mean   3.000000  271.000000  670.000000   4.20000  26.500000
# std    1.581139  485.362408  192.353841   0.83666  48.335632
# min    1.000000   22.000000  450.000000   3.00000   2.000000
# 25%    2.000000   26.500000  500.000000   4.00000   2.000000
# 50%    3.000000   31.500000  700.000000   4.00000   2.500000
# 75%    4.000000  276.000000  800.000000   5.00000  27.000000
# max    5.000000  999.000000  900.000000   5.00000  99.000000

# %%
employees
# Out:
#    id   name    age  salary       city  name_len  onlik
# a   1    Ali    NaN     500   Toshkent         3    NaN
# b   2   Vali  999.0     700  Samarqand         4   99.0
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0

# %%
# 26
employees[employees["age"]>25]
# Out:
#    id   name    age  salary       city  name_len  onlik
# b   2   Vali  999.0     700  Samarqand         4   99.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0

# %%
# 27
employees[employees["salary"]>=700]
# Out:
#    id   name    age  salary       city  name_len  onlik
# b   2   Vali  999.0     700  Samarqand         4   99.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0

# %%
# 28
employees[employees["city"]=="Toshkent"]
# Out:
#    id   name   age  salary      city  name_len  onlik
# a   1    Ali   NaN     500  Toshkent         3    NaN
# d   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 29
employees[(employees["age"]<30) | (employees["salary"]>600)]
# Out:
#    id   name    age  salary       city  name_len  onlik
# b   2   Vali  999.0     700  Samarqand         4   99.0
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0

# %%
# 30
employees[(employees["city"]=="Toshkent") | (employees["city"]=="Buxoro")]
# Out:
#    id   name   age  salary      city  name_len  onlik
# a   1    Ali   NaN     500  Toshkent         3    NaN
# c   3  Hasan  22.0     450    Buxoro         5    2.0
# d   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 31
employees[employees["name"]=="Ali"]
# Out:
#    id name  age  salary      city  name_len  onlik
# a   1  Ali  NaN     500  Toshkent         3    NaN

# %%
# 32
employees[employees["salary"].between(500,800)]
# Out:
#    id  name    age  salary       city  name_len  onlik
# a   1   Ali    NaN     500   Toshkent         3    NaN
# b   2  Vali  999.0     700  Samarqand         4   99.0
# e   5  Olim   28.0     800  Samarqand         4    2.0

# %%
# 33
employees[employees["age"]%2==0]
# Out:
#    id   name   age  salary       city  name_len  onlik
# c   3  Hasan  22.0     450     Buxoro         5    2.0
# e   5   Olim  28.0     800  Samarqand         4    2.0

# %%
#34
employees[employees["name"].str.startswith("H")]
# Out:
#    id   name   age  salary      city  name_len  onlik
# c   3  Hasan  22.0     450    Buxoro         5    2.0
# d   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 35
employees[employees["name"].str.contains("a")]
# Out:
#    id   name    age  salary       city  name_len  onlik
# b   2   Vali  999.0     700  Samarqand         4   99.0
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0

# %%
# 36
employees[employees["age"].isnull()]
# Out:
#    id name  age  salary      city  name_len  onlik
# a   1  Ali  NaN     500  Toshkent         3    NaN

# %%
# 37
employees[employees["salary"].notnull()]
# Out:
#    id   name    age  salary       city  name_len  onlik
# a   1    Ali    NaN     500   Toshkent         3    NaN
# b   2   Vali  999.0     700  Samarqand         4   99.0
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0

# %%
# 38
employees[employees["name"].str.len()>4]
# Out:
#    id   name   age  salary      city  name_len  onlik
# c   3  Hasan  22.0     450    Buxoro         5    2.0
# d   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 39
employees[employees["salary"]==employees["salary"].max()]
# Out:
#    id   name   age  salary      city  name_len  onlik
# d   4  Husan  35.0     900  Toshkent         5    3.0

# %%
# 40
employees[employees["salary"]==employees["salary"].min()]
# Out:
#    id   name   age  salary    city  name_len  onlik
# c   3  Hasan  22.0     450  Buxoro         5    2.0

# %%
# 41
employees.sort_values(["age"])
# Out:
#    id   name    age  salary       city  name_len  onlik
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# e   5   Olim   28.0     800  Samarqand         4    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# b   2   Vali  999.0     700  Samarqand         4   99.0
# a   1    Ali    NaN     500   Toshkent         3    NaN

# %%
# 42
employees.sort_values(["salary"],ascending=False)
# Out:
#    id   name    age  salary       city  name_len  onlik
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0
# b   2   Vali  999.0     700  Samarqand         4   99.0
# a   1    Ali    NaN     500   Toshkent         3    NaN
# c   3  Hasan   22.0     450     Buxoro         5    2.0

# %%
# 43
employees.sort_values(["city","age"])
# Out:
#    id   name    age  salary       city  name_len  onlik
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# e   5   Olim   28.0     800  Samarqand         4    2.0
# b   2   Vali  999.0     700  Samarqand         4   99.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# a   1    Ali    NaN     500   Toshkent         3    NaN

# %%
# 44
employees.sort_values(["name"],ascending=True)
# Out:
#    id   name    age  salary       city  name_len  onlik
# a   1    Ali    NaN     500   Toshkent         3    NaN
# c   3  Hasan   22.0     450     Buxoro         5    2.0
# d   4  Husan   35.0     900   Toshkent         5    3.0
# e   5   Olim   28.0     800  Samarqand         4    2.0
# b   2   Vali  999.0     700  Samarqand         4   99.0

# %%
# 45
employees["len"] = employees["name"].str.len()
employees.sort_values("len",ascending=True)
# Out:
#    id   name    age  salary       city  name_len  onlik  len
# a   1    Ali    NaN     500   Toshkent         3    NaN    3
# b   2   Vali  999.0     700  Samarqand         4   99.0    4
# e   5   Olim   28.0     800  Samarqand         4    2.0    4
# c   3  Hasan   22.0     450     Buxoro         5    2.0    5
# d   4  Husan   35.0     900   Toshkent         5    3.0    5

# %%
# 46
orders.sort_values(["amount"])
# Out:
#    order_id  user_id  amount
# 4       105        3      60
# 3       104        3      80
# 0       101        1     120
# 1       102        1     150
# 2       103        2     300
# 5       106        5     500

# %%
# 47
sales.sort_values(["sales"])
# Out:
#         date  sales  week  month
# 4 2024-01-05     80     0      1
# 3 2024-01-04     90     0      1
# 0 2024-01-01    100     0      1
# 1 2024-01-02    120     0      1
# 2 2024-01-03    130     0      1
# 7 2024-01-08    150     1      1
# 8 2024-01-09    170     1      1
# 5 2024-01-06    200     0      1
# 6 2024-01-07    220     1      1
# 9 2024-01-10    300     1      1

# %%
# 48
employees.sort_values(by=["salary","city"],ascending=[False,True])
# Out:
#    id   name    age  salary       city  name_len  onlik  len
# d   4  Husan   35.0     900   Toshkent         5    3.0    5
# e   5   Olim   28.0     800  Samarqand         4    2.0    4
# b   2   Vali  999.0     700  Samarqand         4   99.0    4
# a   1    Ali    NaN     500   Toshkent         3    NaN    3
# c   3  Hasan   22.0     450     Buxoro         5    2.0    5

# %%
# 49
employees.sort_values(["salary"],ascending=False).head(3)
# Out:
#    id   name    age  salary       city  name_len  onlik  len
# d   4  Husan   35.0     900   Toshkent         5    3.0    5
# e   5   Olim   28.0     800  Samarqand         4    2.0    4
# b   2   Vali  999.0     700  Samarqand         4   99.0    4

# %%
# 50
employees.sort_values(["salary"],ascending=False).tail(2)
# Out:
#    id   name   age  salary      city  name_len  onlik  len
# a   1    Ali   NaN     500  Toshkent         3    NaN    3
# c   3  Hasan  22.0     450    Buxoro         5    2.0    5

# %%
# 51
employees.loc[1,"city"]=None
employees
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# a  1.0    Ali    NaN   500.0   Toshkent       3.0    NaN  3.0
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0
# 1  NaN    NaN    NaN     NaN       None       NaN    NaN  NaN

# %%
# 52
employees.isna()
# Out:
#       id   name    age  salary   city  name_len  onlik    len
# a  False  False   True   False  False     False   True  False
# b  False  False  False   False  False     False  False  False
# c  False  False  False   False  False     False  False  False
# d  False  False  False   False  False     False  False  False
# e  False  False  False   False  False     False  False  False
# 1   True   True   True    True   True      True   True   True

# %%
# 53
employees.notna()
# Out:
#       id   name    age  salary   city  name_len  onlik    len
# a   True   True  False    True   True      True  False   True
# b   True   True   True    True   True      True   True   True
# c   True   True   True    True   True      True   True   True
# d   True   True   True    True   True      True   True   True
# e   True   True   True    True   True      True   True   True
# 1  False  False  False   False  False     False  False  False

# %%
# 54
employees.dropna(how="any")
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0

# %%
# 55
employees.columns[employees.isna().any()]
# Out:
# Index(['id', 'name', 'age', 'salary', 'city', 'name_len', 'onlik', 'len'], dtype='object')

# %%
# 56
employees.fillna("unknown")
# Out:
#         id     name      age   salary       city name_len    onlik      len
# a      1.0      Ali  unknown    500.0   Toshkent      3.0  unknown      3.0
# b      2.0     Vali    999.0    700.0  Samarqand      4.0     99.0      4.0
# c      3.0    Hasan     22.0    450.0     Buxoro      5.0      2.0      5.0
# d      4.0    Husan     35.0    900.0   Toshkent      5.0      3.0      5.0
# e      5.0     Olim     28.0    800.0  Samarqand      4.0      2.0      4.0
# 1  unknown  unknown  unknown  unknown    unknown  unknown  unknown  unknown

# %%
# 57
employees["age"].fillna(0)
# Out:
# a      0.0
# b    999.0
# c     22.0
# d     35.0
# e     28.0
# 1      0.0
# Name: age, dtype: float64

# %%
# 58
employees["salary"].fillna(employees["salary"].mean())
# Out:
# a    500.0
# b    700.0
# c    450.0
# d    900.0
# e    800.0
# 1    670.0
# Name: salary, dtype: float64

# %%
# 59
employees.isna().sum()
# Out:
# id          1
# name        1
# age         2
# salary      1
# city        1
# name_len    1
# onlik       2
# len         1
# dtype: int64

# %%
# 60
employees.isna().sum().max()
# Out:
# 2

# %%
# 61
employees.dropna(how="any")
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0

# %%
# 62
employees.dropna(how="all")
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# a  1.0    Ali    NaN   500.0   Toshkent       3.0    NaN  3.0
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0

# %%
# 63
nan_percentage = employees.isna().any(axis=1).mean() * 100
print(nan_percentage)
# Out:
# 33.33333333333333

# %%
employees
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# a  1.0    Ali    NaN   500.0   Toshkent       3.0    NaN  3.0
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0
# 1  NaN    NaN    NaN     NaN       None       NaN    NaN  NaN

# %%
employees.loc[1,"age"] = None
employees
# Out:
#     id   name    age  salary       city  name_len  onlik  len
# a  1.0    Ali    NaN   500.0   Toshkent       3.0    NaN  3.0
# b  2.0   Vali  999.0   700.0  Samarqand       4.0   99.0  4.0
# c  3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0  5.0
# d  4.0  Husan   35.0   900.0   Toshkent       5.0    3.0  5.0
# e  5.0   Olim   28.0   800.0  Samarqand       4.0    2.0  4.0
# 1  NaN    NaN    NaN     NaN       None       NaN    NaN  NaN

# %%
# 64
employees = employees.fillna(999)
employees
# Out:
#       id   name    age  salary       city  name_len  onlik    len
# a    1.0    Ali  999.0   500.0   Toshkent       3.0  999.0    3.0
# b    2.0   Vali  999.0   700.0  Samarqand       4.0   99.0    4.0
# c    3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0    5.0
# d    4.0  Husan   35.0   900.0   Toshkent       5.0    3.0    5.0
# e    5.0   Olim   28.0   800.0  Samarqand       4.0    2.0    4.0
# 1  999.0    999  999.0   999.0        999     999.0  999.0  999.0

# %%
# 65
employees.loc[0,"age"] = None
employees.dropna().reset_index(drop=True)
# Out:
#       id   name    age  salary       city  name_len  onlik    len
# 0    1.0    Ali  999.0   500.0   Toshkent       3.0  999.0    3.0
# 1    2.0   Vali  999.0   700.0  Samarqand       4.0   99.0    4.0
# 2    3.0  Hasan   22.0   450.0     Buxoro       5.0    2.0    5.0
# 3    4.0  Husan   35.0   900.0   Toshkent       5.0    3.0    5.0
# 4    5.0   Olim   28.0   800.0  Samarqand       4.0    2.0    4.0
# 5  999.0    999  999.0   999.0        999     999.0  999.0  999.0

# %%
# NONE qimatlar boyicha yana 20 ta masala

# %%
# 66
data1 = {
    "id": [1, 2, 3, 4],
    "age": [23, None, 45, None]
}
data1 = df(data1)
data1[data1.isna().any(axis=1)]
# Out:
#    id  age
# 1   2  NaN
# 3   4  NaN

# %%
# 67
data2 = {
    "user": ["Ali", "Vali", "Hasan", "Husan"],
    "score": [10, None, 22, None]
}
data2 = df(data2)
data2[data2.notna().all(axis=1)]
# Out:
#     user  score
# 0    Ali   10.0
# 2  Hasan   22.0

# %%
# 68
data3 = {
    "name": ["A", "B", "C", "D"],
    "value": [None, 3, None, 7]
}
data3 = df(data3)
data3.isna().sum()
# Out:
# name     0
# value    2
# dtype: int64

# %%
# 69
data4 = {
    "a": [1, None, 3, None],
    "b": [None, 2, None, 4]
}
data4 = df(data4)
data4.dropna()
# Out:
# Empty DataFrame
# Columns: [a, b]
# Index: []

# %%
# 70
data5 = {
    "x": [None, None, 3],
    "y": [None, 5, None]
}
data5 = df(data5)
data5.dropna(how="all")
# Out:
#      x    y
# 1  NaN  5.0
# 2  3.0  NaN

# %%
# 71
data6 = {
    "points": [10, None, 30, None, 50]
}
data6 = df(data6)
data6 = data6.fillna(0)
data6
# Out:
#    points
# 0    10.0
# 1     0.0
# 2    30.0
# 3     0.0
# 4    50.0

# %%
# 72
data7 = {
    "salary": [1000, None, 1500, None, 2000]
}
data7 = df(data7)
data7 = data7.fillna(data7.mean(numeric_only=True))
data7
# Out:
#    salary
# 0  1000.0
# 1  1500.0
# 2  1500.0
# 3  1500.0
# 4  2000.0

# %%
# 73
data8 = {
    "temp": [20, None, None, 25, None, 30]
}
data8 = df(data8)
data8 = data8.fillna(data8.shift(1))
data8
# Out:
#    temp
# 0  20.0
# 1  20.0
# 2   NaN
# 3  25.0
# 4  25.0
# 5  30.0

# %%
# 74
data9 = {
    "rate": [None, 5, None, None, 9]
}
data9 = df(data9)
data9 = data9.fillna(data9.shift(-1))
data9
# Out:
#    rate
# 0   5.0
# 1   5.0
# 2   NaN
# 3   9.0
# 4   9.0

# %%
# 75
data10 = {
    "col1": [None, None, None],
    "col2": [1, None, 2],
    "col3": [None, None, None]
}
data10 = df(data10)
data10.isna().all()
# Out:
# col1     True
# col2    False
# col3     True
# dtype: bool

# %%
# 76
data11 = {
    "a": [1, None, 3],
    "b": [None, 2, None],
    "c": [5, None, 7]
}
data11 = df(data11)
data11.isna().sum(axis=1)
# Out:
# 0    1
# 1    2
# 2    1
# dtype: int64

# %%
# 77
data12 = {
    "name": ["Ali", "Vali", "Hasan"],
    "score": [10, None, 30],
    "status": ["ok", "ok", "ok"]
}
data12 = df(data12)
data12.loc[data12["score"].isna(),"status"] = "missing"
data12
# Out:
#     name  score   status
# 0    Ali   10.0       ok
# 1   Vali    NaN  missing
# 2  Hasan   30.0       ok

# %%
# 78
data13 = {
    "id": [1, 2, 3, 4],
    "value": [5, None, 7, None]
}
data13 = df(data13)
data13_new =data13[data13["value"].isna()]
data13_new
# Out:
#    id  value
# 1   2    NaN
# 3   4    NaN

# %%
# 79
data14 = {
    "a": [1, 2, None],
    "b": [None, 3, None],
    "c": [4, 5, 6]
}
data14 = df(data14)
data14.columns[data14.isna().any()]
# Out:
# Index(['a', 'b'], dtype='object')

# %%
# 80
data15 = {
    "x": [None, 2, None, 4],
    "y": [5, 7, 7, None]
}
data15 = df(data15)
data15_new = data15[data15["x"].notna() & data15["y"].notna()]
data15_new
# Out:
#      x    y
# 1  2.0  7.0

# %%
# 81
data16 = {
    "price": [100, None, 200, None]
}
data16 = df(data16)
data16.fillna(data16.max())
# Out:
#    price
# 0  100.0
# 1  200.0
# 2  200.0
# 3  200.0

# %%
# 82
data17 = {
    "data": [None, "A", None, "B"]
}
data17 = df(data17)
data17.isna()
# Out:
#     data
# 0   True
# 1  False
# 2   True
# 3  False

# %%
# 83
data18 = {
    "val": [10, None, 30, None, 50]
}
data18 = df(data18)
data18.loc[data18["val"].isna()].index
# Out:
# Index([1, 3], dtype='int64')

# %%
# 84
data19 = {
    "nums": [10, None, 30, 40, None]
}
data19 = df(data19)
data19.fillna(data19["nums"].median())
# Out:
#    nums
# 0  10.0
# 1  30.0
# 2  30.0
# 3  40.0
# 4  30.0

# %%
# 85
data20 = {
    "group": ["A", "A", "B", "B", "B"],
    "value": [10, None, None, 30, None]
}
data20 = df(data20)
data20["value"] = data20.groupby("group")["value"].transform(
    lambda x: x.fillna(x.mean()))
data20
# Out:
#   group  value
# 0     A   10.0
# 1     A   10.0
# 2     B   30.0
# 3     B   30.0
# 4     B   30.0

# %%
# 86
employees.groupby("city")["salary"].sum()
# Out:
# city
# 999           999.0
# Buxoro        450.0
# Samarqand    1500.0
# Toshkent     1400.0
# Name: salary, dtype: float64

# %%
# 87
employees.groupby("city")["age"].mean()
# Out:
# city
# 999          999.0
# Buxoro        22.0
# Samarqand    513.5
# Toshkent     517.0
# Name: age, dtype: float64

# %%
# 88
employees.groupby("salary")["city"].count()
# Out:
# salary
# 450.0    1
# 500.0    1
# 700.0    1
# 800.0    1
# 900.0    1
# 999.0    1
# Name: city, dtype: int64

# %%
# 89
employees.groupby("city")["salary"].max()
# Out:
# city
# 999          999.0
# Buxoro       450.0
# Samarqand    800.0
# Toshkent     900.0
# Name: salary, dtype: float64

# %%
# 90
employees.groupby("city")["salary"].agg(["sum","mean","count"])
# Out:
#               sum   mean  count
# city
# 999         999.0  999.0      1
# Buxoro      450.0  450.0      1
# Samarqand  1500.0  750.0      2
# Toshkent   1400.0  700.0      2

# %%
# 91
orders.groupby("user_id")["amount"].sum()
# Out:
# user_id
# 1    270
# 2    300
# 3    140
# 5    500
# Name: amount, dtype: int64

# %%
# 92
employees.groupby("age")["salary"].mean()
# Out:
# age
# 22.0     450.0
# 28.0     800.0
# 35.0     900.0
# 999.0    733.0
# Name: salary, dtype: float64

# %%
# 93
employees.groupby("city")["age"].max()
# Out:
# city
# 999          999.0
# Buxoro        22.0
# Samarqand    999.0
# Toshkent     999.0
# Name: age, dtype: float64

# %%
# 94
employees.groupby("city")["salary"].median()
# Out:
# city
# 999          999.0
# Buxoro       450.0
# Samarqand    750.0
# Toshkent     700.0
# Name: salary, dtype: float64

# %%
# 95
employees.groupby("city")["salary"].std()
# Out:
# city
# 999                 NaN
# Buxoro              NaN
# Samarqand     70.710678
# Toshkent     282.842712
# Name: salary, dtype: float64

# %%
# 96
employees["name_len"] = employees["name"].str.len()
employees.groupby("name_len").size()
# Out:
# name_len
# 3.0    1
# 4.0    2
# 5.0    2
# dtype: int64

# %%
# 97
orders.groupby("user_id")["order_id"].count()
# Out:
# user_id
# 1    2
# 2    1
# 3    2
# 5    1
# Name: order_id, dtype: int64

# %%
# 98
orders
orders.groupby("user_id")["amount"].mean()
# Out:
# user_id
# 1    135.0
# 2    300.0
# 3     70.0
# 5    500.0
# Name: amount, dtype: float64

# %%
# 99
employees["onlik"] = employees["age"]//10
employees.groupby("onlik").count()
# Out:
#        id  name  age  salary  city  name_len  len
# onlik
# 2.0     2     2    2       2     2         2    2
# 3.0     1     1    1       1     1         1    1
# 99.0    3     3    3       3     3         2    3

# %%
# 100
employees.groupby(["city","age"]).count()
# Out:
#                  id  name  salary  name_len  onlik  len
# city      age
# 999       999.0   1     1       1         0      1    1
# Buxoro    22.0    1     1       1         1      1    1
# Samarqand 28.0    1     1       1         1      1    1
#           999.0   1     1       1         1      1    1
# Toshkent  35.0    1     1       1         1      1    1
#           999.0   1     1       1         1      1    1

# %%
# 101
products.groupby("price").count()
# Out:
#        product_id  name
# price
# 20              1     1
# 30              1     1
# 150             1     1
# 500             1     1

# %%
# 102
employees[employees["salary"]>600].groupby("city").count()
# Out:
#            id  name  age  salary  name_len  onlik  len
# city
# 999         1     1    1       1         0      1    1
# Samarqand   2     2    2       2         2      2    2
# Toshkent    1     1    1       1         1      1    1

# %%
# 103
employees.groupby("city")["age"].min()
# Out:
# city
# 999          999.0
# Buxoro        22.0
# Samarqand     28.0
# Toshkent      35.0
# Name: age, dtype: float64

# %%
# 104
sales["week"] = sales["date"].dt.day//7
sales.groupby("week").count()
# Out:
#       date  sales  month
# week
# 0        6      6      6
# 1        4      4      4

# %%
# 105
sales["month"] = sales["date"].dt.month
sales.groupby("month").count()
# Out:
#        date  sales  week
# month
# 1        10     10    10

# %%
# 106
employees.merge(orders,left_on="id",right_on="user_id")
# Out:
#    id   name  age  salary       city  order_id  user_id  amount
# 0   1    Ali   25     500   Toshkent       101        1     120
# 1   1    Ali   25     500   Toshkent       102        1     150
# 2   2   Vali   30     700  Samarqand       103        2     300
# 3   3  Hasan   22     450     Buxoro       104        3      80
# 4   3  Hasan   22     450     Buxoro       105        3      60
# 5   5   Olim   28     800  Samarqand       106        5     500

# %%
# 107
employees.merge(orders,left_on="id",right_on="user_id",how="left")
# Out:
#    id   name  age  salary       city  order_id  user_id  amount
# 0   1    Ali   25     500   Toshkent     101.0      1.0   120.0
# 1   1    Ali   25     500   Toshkent     102.0      1.0   150.0
# 2   2   Vali   30     700  Samarqand     103.0      2.0   300.0
# 3   3  Hasan   22     450     Buxoro     104.0      3.0    80.0
# 4   3  Hasan   22     450     Buxoro     105.0      3.0    60.0
# 5   4  Husan   35     900   Toshkent       NaN      NaN     NaN
# 6   5   Olim   28     800  Samarqand     106.0      5.0   500.0

# %%
# 108
employees.merge(orders,left_on="id",right_on="user_id",how="right")
# Out:
#    id   name  age  salary       city  order_id  user_id  amount
# 0   1    Ali   25     500   Toshkent       101        1     120
# 1   1    Ali   25     500   Toshkent       102        1     150
# 2   2   Vali   30     700  Samarqand       103        2     300
# 3   3  Hasan   22     450     Buxoro       104        3      80
# 4   3  Hasan   22     450     Buxoro       105        3      60
# 5   5   Olim   28     800  Samarqand       106        5     500

# %%
# 109
employees.merge(orders,left_on="id",right_on="user_id",how="outer")
# Out:
#    id   name  age  salary       city  order_id  user_id  amount
# 0   1    Ali   25     500   Toshkent     101.0      1.0   120.0
# 1   1    Ali   25     500   Toshkent     102.0      1.0   150.0
# 2   2   Vali   30     700  Samarqand     103.0      2.0   300.0
# 3   3  Hasan   22     450     Buxoro     104.0      3.0    80.0
# 4   3  Hasan   22     450     Buxoro     105.0      3.0    60.0
# 5   4  Husan   35     900   Toshkent       NaN      NaN     NaN
# 6   5   Olim   28     800  Samarqand     106.0      5.0   500.0

# %%
# 110
df.merge(employees,orders,left_on="id",right_on="user_id",how="inner")
# Out:
#    id   name  age  salary       city  order_id  user_id  amount
# 0   1    Ali   25     500   Toshkent       101        1     120
# 1   1    Ali   25     500   Toshkent       102        1     150
# 2   2   Vali   30     700  Samarqand       103        2     300
# 3   3  Hasan   22     450     Buxoro       104        3      80
# 4   3  Hasan   22     450     Buxoro       105        3      60
# 5   5   Olim   28     800  Samarqand       106        5     500

# %%
# 111
employees[~employees["id"].isin(orders["user_id"])]
# Out:
#    id   name  age  salary      city
# 3   4  Husan   35     900  Toshkent

# %%
# 112
employees["order"] = range(1,len(employees)+1)
employees
# Out:
#    id   name  age  salary       city  order
# 0   1    Ali   25     500   Toshkent      1
# 1   2   Vali   30     700  Samarqand      2
# 2   3  Hasan   22     450     Buxoro      3
# 3   4  Husan   35     900   Toshkent      4
# 4   5   Olim   28     800  Samarqand      5

# %%
# 113
employees.merge(orders.groupby("user_id")["amount"].sum(),left_on="id",right_on="user_id",how="outer")
# employees = employees.drop("t_amount",axis=1)
# Out:
#    id   name  age  salary       city  order  amount
# 0   1    Ali   25     500   Toshkent      1   270.0
# 1   2   Vali   30     700  Samarqand      2   300.0
# 2   3  Hasan   22     450     Buxoro      3   140.0
# 3   4  Husan   35     900   Toshkent      4     NaN
# 4   5   Olim   28     800  Samarqand      5   500.0

# %%
# 114
products.index.name = "id"
orders.merge(products,left_on="order_id",right_on="id",how="left")
# Out:
#    order_id  user_id  amount  product_id name  price
# 0       101        1     120         NaN  NaN    NaN
# 1       102        1     150         NaN  NaN    NaN
# 2       103        2     300         NaN  NaN    NaN
# 3       104        3      80         NaN  NaN    NaN
# 4       105        3      60         NaN  NaN    NaN
# 5       106        5     500         NaN  NaN    NaN

# %%
# 115
employees.index.name = "idx"
employees.merge(employees,left_on="idx",right_on="id",how="left")
# Out:
#    id_x name_x  age_x  salary_x     city_x  id_y name_y  age_y  salary_y  \
# 0     1    Ali     25       500   Toshkent   NaN    NaN    NaN       NaN
# 1     2   Vali     30       700  Samarqand   1.0    Ali   25.0     500.0
# 2     3  Hasan     22       450     Buxoro   2.0   Vali   30.0     700.0
# 3     4  Husan     35       900   Toshkent   3.0  Hasan   22.0     450.0
# 4     5   Olim     28       800  Samarqand   4.0  Husan   35.0     900.0
#
#       city_y
# 0        NaN
# 1   Toshkent
# 2  Samarqand
# 3     Buxoro
# 4   Toshkent

# %%
# 116
employees.merge(orders,left_on="id",right_on="user_id").groupby("user_id")["salary"].sum()
# Out:
# user_id
# 1    1000
# 2     700
# 3     900
# 5     800
# Name: salary, dtype: int64
